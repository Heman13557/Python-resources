# %%
#import the library

import matplotlib.pyplot as plt

# %%
# co-ordinates for a straight line

x=[1,2,3,4,5,6,7,8,9]

y=[9,8,7,6,5,4,3,2,1]

# %%
# now plot method for plotting the gragh

plt.plot(x,y)

# %%
# show() is used important when you are not using ipython shell

plt.show()

# %%
# for colouring the line
plt.plot(x,y,color='red')

# %%
# giving titles 

plt.xlabel('Overs')

plt.ylabel('Runs')

plt.title('INDIA Vs ENGLAND')

plt.plot(x,y)
