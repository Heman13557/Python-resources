# %%
import numpy as np
import matplotlib.pyplot as plt

teams= ["India","Pakistan","Sri Lanka","West Indies","Australia","England"]

wins = [2,1,1,2,5,1]

cols = ['Blue','Green','brown','red','yellow','white']

plt.pie(wins,colors=cols,labels=teams,shadow=True)

plt.title('World cup')

plt.show()
